# %%
import os
import datetime
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
# Import dataset
train = pd.read_csv('/content/train.csv')
test= pd.read_csv('/content/test.csv')
train.head()
# Out:
#               datetime  season  holiday  workingday  weather  temp   atemp  \
# 0  2011-01-01 00:00:00       1        0           0        1  9.84  14.395
# 1  2011-01-01 01:00:00       1        0           0        1  9.02  13.635
# 2  2011-01-01 02:00:00       1        0           0        1  9.02  13.635
# 3  2011-01-01 03:00:00       1        0           0        1  9.84  14.395
# 4  2011-01-01 04:00:00       1        0           0        1  9.84  14.395
#
#    humidity  windspeed  casual  registered  count
# 0        81        0.0       3          13     16
# 1        80        0.0       8          32     40
# 2        80        0.0       5          27     32
# 3        75        0.0       3          10     13
# 4        75        0.0       0           1      1

# %%
test.head()
# Out:
#               datetime  season  holiday  workingday  weather   temp   atemp  \
# 0  2011-01-20 00:00:00       1        0           1        1  10.66  11.365
# 1  2011-01-20 01:00:00       1        0           1        1  10.66  13.635
# 2  2011-01-20 02:00:00       1        0           1        1  10.66  13.635
# 3  2011-01-20 03:00:00       1        0           1        1  10.66  12.880
# 4  2011-01-20 04:00:00       1        0           1        1  10.66  12.880
#
#    humidity  windspeed
# 0        56    26.0027
# 1        56     0.0000
# 2        56     0.0000
# 3        56    11.0014
# 4        56    11.0014

# %%
# get the dataset info
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10886 entries, 0 to 10885
# Data columns (total 12 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   datetime    10886 non-null  object
#  1   season      10886 non-null  int64
#  2   holiday     10886 non-null  int64
#  3   workingday  10886 non-null  int64
#  4   weather     10886 non-null  int64
#  5   temp        10886 non-null  float64
#  6   atemp       10886 non-null  float64
#  7   humidity    10886 non-null  int64
#  8   windspeed   10886 non-null  float64
#  9   casual      10886 non-null  int64
#  10  registered  10886 non-null  int64
#  11  count       10886 non-null  int64
# dtypes: float64(3), int64(8), object(1)
# memory usage: 1020.7+ KB

# %%
test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6493 entries, 0 to 6492
# Data columns (total 9 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   datetime    6493 non-null   object
#  1   season      6493 non-null   int64
#  2   holiday     6493 non-null   int64
#  3   workingday  6493 non-null   int64
#  4   weather     6493 non-null   int64
#  5   temp        6493 non-null   float64
#  6   atemp       6493 non-null   float64
#  7   humidity    6493 non-null   int64
#  8   windspeed   6493 non-null   float64
# dtypes: float64(3), int64(5), object(1)
# memory usage: 456.7+ KB

# %%
train.describe()
# Out:
#              season       holiday    workingday       weather         temp  \
# count  10886.000000  10886.000000  10886.000000  10886.000000  10886.00000
# mean       2.506614      0.028569      0.680875      1.418427     20.23086
# std        1.116174      0.166599      0.466159      0.633839      7.79159
# min        1.000000      0.000000      0.000000      1.000000      0.82000
# 25%        2.000000      0.000000      0.000000      1.000000     13.94000
# 50%        3.000000      0.000000      1.000000      1.000000     20.50000
# 75%        4.000000      0.000000      1.000000      2.000000     26.24000
# max        4.000000      1.000000      1.000000      4.000000     41.00000
#
#               atemp      humidity     windspeed        casual    registered  \
# count  10886.000000  10886.000000  10886.000000  10886.000000  10886.000000
# mean      23.655084     61.886460     12.799395     36.021955    155.552177
# std        8.474601     19.245033      8.164537     49.960477    151.039033
# min        0.760000      0.000000      0.000000      0.000000      0.000000
# 25%       16.665000     47.000000      7.001500      4.000000     36.000000
# 50%       24.240000     62.000000     12.998000     17.000000    118.000000
# 75%       31.060000     77.000000     16.997900     49.000000    222.000000
# max       45.455000    100.000000     56.996900    367.000000    886.000000
#
#               count
# count  10886.000000
# mean     191.574132
# std      181.144454
# min        1.000000
# 25%       42.000000
# 50%      145.000000
# 75%      284.000000
# max      977.000000

# %%
#Visualize the dataset
#boxplot of count
sns.boxplot(x='count',data = train, color = 'mediumpurple')
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
#Histogram of count column
sns.set(style='darkgrid')
sns.distplot(train['count'],bins=100,color='green')
plt.show()
# Out:
# <ipython-input-19-2b8cb278a5be>:3: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(train['count'],bins=100,color='green')

# %%
from csv import field_size_limit
#scatter the plot between count and each numeric features
fields =[f for f in train]
fields = fields[5: -3]
print(fields)


fig=plt.figure(figsize=(17,3))
for i, f in enumerate(fields):
    ax = fig.add_subplot(1,4,i+1)  # Create subplot
    ax.scatter(train[f], train['count'])  # Scatter plot
    ax.set_xlabel(f)  # Set xlabel
    ax.set_ylabel('count')  # Set ylabel

  # Adjust layout to prevent overlap
plt.show()  # Show the plot
# Out:
# ['temp', 'atemp', 'humidity', 'windspeed']

# %%
#boxplot between count and each categorical features
fig,axes=plt.subplots(nrows=2,ncols=2)
fig.set_size_inches(20,10)
sns.boxplot(data=train,y='count',x='season',ax=axes[0][0])
sns.boxplot(data=train,y='count',x='holiday',ax=axes[0][1])
sns.boxplot(data=train,y='count',x='workingday',ax=axes[1][0])
sns.boxplot(data=train,y='count',x='weather',ax=axes[1][1])

axes[0][0].set(xlabel='season',ylabel='count')
axes[0][1].set(xlabel='holiday',ylabel='count')
axes[1][0].set(xlabel='workingday',ylabel='count')
axes[1][1].set(xlabel='weather',ylabel='count')
# Out:
# [Text(0.5, 0, 'weather'), Text(0, 0.5, 'count')]

# %%
#corelation
plt.figure(figsize=(10,10))
# Select only numeric columns for correlation calculation
numeric_train = train.select_dtypes(include=['number'])
sns.heatmap(numeric_train.corr('pearson'),vmin=-1,vmax=1,cmap='coolwarm',annot=True,square=True)
# Out:
# <Axes: >

# %%
#converting the datetime column to each elements(year,month,day,dayof week,hour)
train['datetime']=pd.to_datetime(train['datetime'])
test['datetime']=pd.to_datetime(test['datetime'])
train.head()
# Out:
#              datetime  season  holiday  workingday  weather  temp   atemp  \
# 0 2011-01-01 00:00:00       1        0           0        1  9.84  14.395
# 1 2011-01-01 01:00:00       1        0           0        1  9.02  13.635
# 2 2011-01-01 02:00:00       1        0           0        1  9.02  13.635
# 3 2011-01-01 03:00:00       1        0           0        1  9.84  14.395
# 4 2011-01-01 04:00:00       1        0           0        1  9.84  14.395
#
#    humidity  windspeed  casual  registered  count
# 0        81        0.0       3          13     16
# 1        80        0.0       8          32     40
# 2        80        0.0       5          27     32
# 3        75        0.0       3          10     13
# 4        75        0.0       0           1      1

# %%
def split_datetime(df):
    if 'datetime' in df.columns:  # Check if 'datetime' column exists
        df['year'] = df['datetime'].apply(lambda t: t.year)
        df['month'] = df['datetime'].apply(lambda t: t.month)
        df['day'] = df['datetime'].apply(lambda t: t.day)
        df['dayofweek'] = df['datetime'].apply(lambda t: t.dayofweek)
        df['hour'] = df['datetime'].apply(lambda t: t.hour)
        df=df.drop(['datetime'],axis=1)
    return df

train = split_datetime(train)
test = split_datetime(test)
# Check if the columns exist before dropping
if 'casual' in train.columns and 'registered' in train.columns:
    train = train.drop(['casual','registered'], axis=1)
else:
    print("Columns 'casual' and/or 'registered' not found in the DataFrame.")
train.head()
# Out:
#    season  holiday  workingday  weather  temp   atemp  humidity  windspeed  \
# 0       1        0           0        1  9.84  14.395        81        0.0
# 1       1        0           0        1  9.02  13.635        80        0.0
# 2       1        0           0        1  9.02  13.635        80        0.0
# 3       1        0           0        1  9.84  14.395        75        0.0
# 4       1        0           0        1  9.84  14.395        75        0.0
#
#    count  year  month  day  dayofweek  hour
# 0     16  2011      1    1          5     0
# 1     40  2011      1    1          5     1
# 2     32  2011      1    1          5     2
# 3     13  2011      1    1          5     3
# 4      1  2011      1    1          5     4

# %%
#boxplot between count and each categorical feature
fig,axes=plt.subplots(nrows=1,ncols=3)
fig.set_size_inches(25,3)
sns.barplot(data=train,x='year',y='count',ax=axes[0])
sns.barplot(data=train,x='month',y='count',ax=axes[1])
sns.lineplot(data=train,x='hour',y='count',ax=axes[2],hue='dayofweek')
# Out:
# <Axes: xlabel='hour', ylabel='count'>

# %%
#count column looks skew
sns.distplot(train['count'])
# Out:
# <ipython-input-26-dfe0740c8850>:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(train['count'])
# <Axes: xlabel='count', ylabel='Density'>

# %%
#take a log for count column
train['count']=np.log(train['count'])
sns.distplot(train['count'])
# Out:
# <ipython-input-27-f2a182b097fe>:3: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(train['count'])
# <Axes: xlabel='count', ylabel='Density'>

# %%
#eliminate outliers
train=train[np.abs(train['count'])-train['count'].mean()<=(3*train['count'].std())]
sns.distplot(train['count'])
# Out:
# <ipython-input-28-e4c2caea0d28>:3: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(train['count'])
# <Axes: xlabel='count', ylabel='Density'>

# %%
#boxplot of count
sns.boxplot(x='count',data=train,color='mediumpurple')
plt.show()

# %%
fig=plt.figure(figsize=(15,15))
for i,f1 in enumerate(fields):
    for j ,f2 in enumerate(fields):
        idx=i*len(fields)+j+1
        ax=fig.add_subplot(len(fields),len(fields),idx)
        ax.scatter(train[f1],train[f2])
        ax.set_ylabel(f1)
        ax.set_xlabel(f2)

plt.show()

# %%
drop_idx = train[(train['atemp'] > 20) & (train['atemp'] < 40) & (train['temp'] > 10) & (train['temp'] < 20)].index
train = train.drop(drop_idx)

# %%
#standard scaling numeric columns
from sklearn.preprocessing import MinMaxScaler

def scaling(df):
    scaler = MinMaxScaler()
    num_cols = ['temp', 'atemp', 'humidity', 'windspeed']  # Define the numerical columns to scale
    df[num_cols] = scaler.fit_transform(df[num_cols])  # Fit and transform the specified columns
    return df

# %%
# Assuming train and test are your dataframes that you want to scale
train = scaling(train)
test = scaling(test)

# %%
train.head()
# Out:
#    season  holiday  workingday  weather      temp     atemp  humidity  \
# 0       1        0           0        1  0.224490  0.305068      0.81
# 1       1        0           0        1  0.204082  0.288064      0.80
# 2       1        0           0        1  0.204082  0.288064      0.80
# 3       1        0           0        1  0.224490  0.305068      0.75
# 4       1        0           0        1  0.224490  0.305068      0.75
#
#    windspeed     count  year  month  day  dayofweek  hour
# 0        0.0  2.772589  2011      1    1          5     0
# 1        0.0  3.688879  2011      1    1          5     1
# 2        0.0  3.465736  2011      1    1          5     2
# 3        0.0  2.564949  2011      1    1          5     3
# 4        0.0  0.000000  2011      1    1          5     4

# %%
#split train & test
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(train.drop(['count'], axis=1), train['count'], test_size=0.3)

# %%
#using metric
def rmsle(y,pred):
  log_y=np.log1p(y)
  log_pred=np.log1p(pred)
  squared_error=(log_y-log_pred)**2
  rmsle_value=(np.sqrt(np.mean(squared_error)))
  return rmsle_value

# %%
from sklearn.linear_model import LinearRegression,Ridge,Lasso
from sklearn.ensemble import RandomForestRegressor,GradientBoostingRegressor
from xgboost import XGBRegressor
from lightgbm import LGBMRegressor # Fixed typo in LGBMRegressor

from sklearn.model_selection import GridSearchCV

# %%
def evaluate(reg_cls,params=None):
  reg=reg_cls() # Instantiate the regressor object here
  if params:
    reg=GridSearchCV(reg,param_grid=params,refit=True)
  reg.fit(x_train,y_train) # Now you can fit the model
  pred=reg.predict(x_test)

  y_test_exp=np.expm1(y_test)
  pred_test_exp=np.expm1(pred)
  print('\n',reg_cls)
  if params:
    print(reg.best_params_)
    reg=reg.best_estimator_
  print(rmsle(y_test_exp,pred_test_exp)) # Call the rmsle function with the correct arguments

  return reg,pred_test_exp # Return pred_test_exp instead of pred_exp

# %%
lr_reg, pred_lr = evaluate(LinearRegression)
rg_reg, pred_rg = evaluate(Ridge)
ls_reg, pred_ls = evaluate(Lasso)
rf_reg, pred_rf = evaluate(RandomForestRegressor)
gb_reg, pred_gb = evaluate(GradientBoostingRegressor)
xg_reg, pred_xg = evaluate(XGBRegressor)
lb_reg, pred_lb = evaluate(LGBMRegressor)





params = {'n_estimators': [100*i for i in range(1, 6)]}
xg_reg, pred_xg = evaluate(XGBRegressor,params)
lg_reg, pred_lg = evaluate(LGBMRegressor,params)
# Out:
#  <class 'sklearn.linear_model._base.LinearRegression'>
# 1.055812287756394
#
#  <class 'sklearn.linear_model._ridge.Ridge'>
# 1.0555894760025029
#
#  <class 'sklearn.linear_model._coordinate_descent.Lasso'>
# 1.2305647911198994
#
#  <class 'sklearn.ensemble._forest.RandomForestRegressor'>
# 0.3352514848092308
#
#  <class 'sklearn.ensemble._gb.GradientBoostingRegressor'>
# 0.4212368188079409
#
#  <class 'xgboost.sklearn.XGBRegressor'>
# 0.3228101965498964
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000266 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 278
# [LightGBM] [Info] Number of data points in the train set: 6458, number of used features: 13
# [LightGBM] [Info] Start training from score 4.556489
#
#  <class 'lightgbm.sklearn.LGBMRegressor'>
# 0.32063937283123956
#
#  <class 'xgboost.sklearn.XGBRegressor'>
# {'n_estimators': 100}
# 0.3228101965498964
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000206 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 275
# [LightGBM] [Info] Number of data points in the train set: 5166, number of used features: 13
# [LightGBM] [Info] Start training from score 4.564440
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000210 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 274
# [LightGBM] [Info] Number of data points in the train set: 5166, number of used features: 13
# [LightGBM] [Info] Start training from score 4.563488
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000206 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 276
# [LightGBM] [Info] Number of data points in the train set: 5166, number of used features: 13
# [LightGBM] [Info] Start training from score 4.548859
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000206 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 275
# [LightGBM] [Info] Number of data points in the train set: 5167, number of used features: 13
# [LightGBM] [Info] Start training from score 4.558068
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000218 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 275
# [LightGBM] [Info] Number of data points in the train set: 5167, number of used features: 13
# [LightGBM] [Info] Start training from score 4.547589
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000318 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 275
# [LightGBM] [Info] Number of data points in the train set: 5166, number of used features: 13
# [LightGBM] [Info] Start training from score 4.564440
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000205 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 274
# [LightGBM] [Info] Number of data points in the train set: 5166, number of used features: 13
# [LightGBM] [Info] Start training from score 4.563488
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000344 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 276
# [LightGBM] [Info] Number of data points in the train set: 5166, number of used features: 13
# [LightGBM] [Info] Start training from score 4.548859
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000206 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 275
# [LightGBM] [Info] Number of data points in the train set: 5167, number of used features: 13
# [LightGBM] [Info] Start training from score 4.558068
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000206 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 275
# [LightGBM] [Info] Number of data points in the train set: 5167, number of used features: 13
# [LightGBM] [Info] Start training from score 4.547589
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000207 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 275
# [LightGBM] [Info] Number of data points in the train set: 5166, number of used features: 13
# [LightGBM] [Info] Start training from score 4.564440
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000214 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 274
# [LightGBM] [Info] Number of data points in the train set: 5166, number of used features: 13
# [LightGBM] [Info] Start training from score 4.563488
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000342 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 276
# [LightGBM] [Info] Number of data points in the train set: 5166, number of used features: 13
# [LightGBM] [Info] Start training from score 4.548859
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000206 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 275
# [LightGBM] [Info] Number of data points in the train set: 5167, number of used features: 13
# [LightGBM] [Info] Start training from score 4.558068
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000205 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 275
# [LightGBM] [Info] Number of data points in the train set: 5167, number of used features: 13
# [LightGBM] [Info] Start training from score 4.547589
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000339 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 275
# [LightGBM] [Info] Number of data points in the train set: 5166, number of used features: 13
# [LightGBM] [Info] Start training from score 4.564440
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000379 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 274
# [LightGBM] [Info] Number of data points in the train set: 5166, number of used features: 13
# [LightGBM] [Info] Start training from score 4.563488
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000379 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 276
# [LightGBM] [Info] Number of data points in the train set: 5166, number of used features: 13
# [LightGBM] [Info] Start training from score 4.548859
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000385 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 275
# [LightGBM] [Info] Number of data points in the train set: 5167, number of used features: 13
# [LightGBM] [Info] Start training from score 4.558068
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000333 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 275
# [LightGBM] [Info] Number of data points in the train set: 5167, number of used features: 13
# [LightGBM] [Info] Start training from score 4.547589
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000372 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 275
# [LightGBM] [Info] Number of data points in the train set: 5166, number of used features: 13
# [LightGBM] [Info] Start training from score 4.564440
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000338 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 274
# [LightGBM] [Info] Number of data points in the train set: 5166, number of used features: 13
# [LightGBM] [Info] Start training from score 4.563488
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000699 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 276
# [LightGBM] [Info] Number of data points in the train set: 5166, number of used features: 13
# [LightGBM] [Info] Start training from score 4.548859
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000240 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 275
# [LightGBM] [Info] Number of data points in the train set: 5167, number of used features: 13
# [LightGBM] [Info] Start training from score 4.558068
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000205 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 275
# [LightGBM] [Info] Number of data points in the train set: 5167, number of used features: 13
# [LightGBM] [Info] Start training from score 4.547589
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000256 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 278
# [LightGBM] [Info] Number of data points in the train set: 6458, number of used features: 13
# [LightGBM] [Info] Start training from score 4.556489
#
#  <class 'lightgbm.sklearn.LGBMRegressor'>
# {'n_estimators': 300}
# 0.31106335930843443

# %%
#important features of model (how important each feature is)
def feature_importance(reg):
  plt.figure(figsize=(20,10))
  print(type(reg))

  df=pd.DataFrame(sorted(zip(x_train.columns,reg.feature_importances_)),columns=['features','values'])
  sns.barplot(x='values',y='features',data=df.sort_values(by='values',ascending=False))
plt.show()

# %%
feature_importance(xg_reg)
# Out:
# <class 'xgboost.sklearn.XGBRegressor'>

# %%
feature_importance(lg_reg)
# Out:
# <class 'lightgbm.sklearn.LGBMRegressor'>

# %%
submission=pd.read_csv('/content/sampleSubmission.csv')
submission.head()
# Out:
#               datetime  count
# 0  2011-01-20 00:00:00      0
# 1  2011-01-20 01:00:00      0
# 2  2011-01-20 02:00:00      0
# 3  2011-01-20 03:00:00      0
# 4  2011-01-20 04:00:00      0

# %%
test.shape
# Out:
# (6493, 13)

# %%
submission.shape
# Out:
# (6493, 2)

# %%
pred=lg_reg.predict(test)
pred_exp=np.expm1(pred)
print(pred_exp)
# Out:
# [  6.81048803   3.36131941   2.30574888 ... 121.97899915  88.74875432
#   53.60168669]

# %%
submission.loc[:,'count']=pred_exp
submission
# Out:
#                  datetime       count
# 0     2011-01-20 00:00:00    6.810488
# 1     2011-01-20 01:00:00    3.361319
# 2     2011-01-20 02:00:00    2.305749
# 3     2011-01-20 03:00:00    1.050748
# 4     2011-01-20 04:00:00    1.410516
# ...                   ...         ...
# 6488  2012-12-31 19:00:00  266.864487
# 6489  2012-12-31 20:00:00  176.154006
# 6490  2012-12-31 21:00:00  121.978999
# 6491  2012-12-31 22:00:00   88.748754
# 6492  2012-12-31 23:00:00   53.601687
#
# [6493 rows x 2 columns]
